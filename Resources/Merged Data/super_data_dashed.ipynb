# %%
#imports
import pandas as pd
import os
from pathlib import Path

# %%
super_undashed = pd.read_csv(
    "NCAA-March-Madness/Resources/super_data.csv")

# %%
super_undashed
# Out:
#                          Team  Years  AST   TO  Ratio        TPG   Avg  3FG%  \
# 0          Michigan (Big Ten)   1213  565  368   1.54   9.435897   NaN  38.5
# 1        UC Irvine (Big West)   1213  580  461   1.26  12.459459   NaN  33.4
# 2           Iowa St. (Big 12)   1213  560  460   1.22  13.142857   NaN  37.4
# 3           Santa Clara (WCC)   1213  560  468   1.20  12.315789   NaN  36.1
# 4           Wichita St. (MVC)   1213  530  492   1.08  12.615385   NaN  33.9
# ...                       ...    ...  ...  ...    ...        ...   ...   ...
# 3711             Siena (MAAC)   2324  342  505   0.68  15.781250  18.8  28.0
# 3712              VMI (SoCon)   2324  335  507   0.66  15.843750  21.0  31.2
# 3713       Alabama A&M (SWAC)   2324  369  565   0.65  16.142857  14.7  28.7
# 3714  Mississippi Val. (SWAC)   2324  271  495   0.55  15.967742  15.8  29.2
# 3715        Coppin St. (MEAC)   2324  240  455   0.53  15.689655  18.6  28.3
#
# ...

# %%
super_undashed['Years'] = super_undashed['Years'].apply(lambda x: str(x))

# %%
super_undashed['Years'] = super_undashed['Years'].apply(lambda x: x[:2] + '-' + x[2:])

# %%
super_dashed = super_undashed

# %%
super_dashed.head(3716)
# Out:
#                          Team  Years  AST   TO  Ratio        TPG   Avg  3FG%  \
# 0          Michigan (Big Ten)  12-13  565  368   1.54   9.435897   NaN  38.5
# 1        UC Irvine (Big West)  12-13  580  461   1.26  12.459459   NaN  33.4
# 2           Iowa St. (Big 12)  12-13  560  460   1.22  13.142857   NaN  37.4
# 3           Santa Clara (WCC)  12-13  560  468   1.20  12.315789   NaN  36.1
# 4           Wichita St. (MVC)  12-13  530  492   1.08  12.615385   NaN  33.9
# ...                       ...    ...  ...  ...    ...        ...   ...   ...
# 3711             Siena (MAAC)  23-24  342  505   0.68  15.781250  18.8  28.0
# 3712              VMI (SoCon)  23-24  335  507   0.66  15.843750  21.0  31.2
# 3713       Alabama A&M (SWAC)  23-24  369  565   0.65  16.142857  14.7  28.7
# 3714  Mississippi Val. (SWAC)  23-24  271  495   0.55  15.967742  15.8  29.2
# 3715        Coppin St. (MEAC)  23-24  240  455   0.53  15.689655  18.6  28.3
#
# ...

# %%
super_dashed.to_csv("super_data_dashed.csv")
