# %%
#imports
import pandas as pd
from pathlib import Path

# %%
#read excel files for assist and turnover ratio
atr2324 = pd.read_excel(
    "Resources/2324_assist_and_turnover_ratio.xlsx")

atr2223 = pd.read_excel(
    "Resources/2223_assist_and_turnover_ratio.xlsx")

atr2122 = pd.read_excel(
    "Resources/2122_assist_and_turnover_ratio.xlsx")

atr2021 = pd.read_excel(
    "Resources/2021_assist_and_turnover_ratio.xlsx")

atr1920 = pd.read_excel(
    "Resources/1920_assist_and_turnover_ratio.xlsx")

atr1819 = pd.read_excel(
    "Resources/1819_assist_and_turnover_ratio.xlsx")

atr1718 = pd.read_excel(
    "Resources/1718_assist_and_turnover_ratio.xlsx")

atr1617 = pd.read_excel(
    "Resources/1617_assist_and_turnover_ratio.xlsx")

atr1516 = pd.read_excel(
    "Resources/1516_assist_and_turnover_ratio.xlsx")

atr1415 = pd.read_excel(
    "Resources/1415_assist_and_turnover_ratio.xlsx")

atr1314 = pd.read_excel(
    "Resources/1314_assist_and_turnover_ratio.xlsx")

atr1213 = pd.read_excel(
    "Resources/1213_assist_and_turnover_ratio.xlsx")

atr1112 = pd.read_excel(
    "Resources/1112_assist_and_turnover_ratio.xlsx")

atr1011 = pd.read_excel(
    "Resources/1011_assist_and_turnover_ratio.xlsx")

atr0910 = pd.read_excel(
    "Resources/0910_assist_and_turnover_ratio.xlsx")

atr0809 = pd.read_excel(
    "Resources/0809_assist_and_turnover_ratio.xlsx")

atr0708 = pd.read_excel(
    "Resources/0708_assist_and_turnover_ratio.xlsx")

# %%
#read excel files for scoring offence
sco2324 = pd.read_excel(
    "Resources/2324_scoring_offence.xlsx")

sco2223 = pd.read_excel(
    "Resources/2223_scoring_offence.xlsx")

sco2122 = pd.read_excel(
    "Resources/2122_scoring_offence.xlsx")

sco2021 = pd.read_excel(
    "Resources/2021_scoring_offence.xlsx")

sco1920 = pd.read_excel(
    "Resources/1920_scoring_offence.xlsx")

sco1819 = pd.read_excel(
    "Resources/1819_scoring_offence.xlsx")

sco1718 = pd.read_excel(
    "Resources/1718_scoring_offence.xlsx")

sco1617 = pd.read_excel(
    "Resources/1617_scoring_offence.xlsx")

sco1516 = pd.read_excel(
    "Resources/1516_scoring_offence.xlsx")

sco1415 = pd.read_excel(
    "Resources/1415_scoring_offence.xlsx")

sco1314 = pd.read_excel(
    "Resources/1314_scoring_offence.xlsx")

sco1213 = pd.read_excel(
    "Resources/1213_scoring_offence.xlsx")

sco1112 = pd.read_excel(
    "Resources/1112_scoring_offence.xlsx")

sco1011 = pd.read_excel(
    "Resources/1011_scoring_offence.xlsx")

sco0910 = pd.read_excel(
    "Resources/0910_scoring_offence.xlsx")

sco0809 = pd.read_excel(
    "Resources/0809_scoring_offence.xlsx")

sco0708 = pd.read_excel(
    "Resources/0708_scoring_offence.xlsx")

sco0607 = pd.read_excel(
    "Resources/0607_scoring_offence.xlsx")

sco0506 = pd.read_excel(
    "Resources/0506_scoring_offence.xlsx")

sco0405 = pd.read_excel(
    "Resources/0405_scoring_offence.xlsx")

sco0304 = pd.read_excel(
    "Resources/0304_scoring_offence.xlsx")

sco0203 = pd.read_excel(
    "Resources/0203_scoring_offence.xlsx")

sco0102 = pd.read_excel(
    "Resources/0102_scoring_offence.xlsx")
